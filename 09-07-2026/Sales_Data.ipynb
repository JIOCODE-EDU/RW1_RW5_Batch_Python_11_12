# %% [markdown]
# # 📊 Customer Sales Analysis Dashboard

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_sales_data.csv')
print("First 5 Records")
print(df.head())
# Out:
# First 5 Records
#   Customer_ID  Gender  Age Region Product_Category  Units_Purchased  \
# 0    CUST0001  Female   51   West           Sports                2
# 1    CUST0002  Female   55   East            Books                1
# 2    CUST0003  Female   50  North        Groceries                5
# 3    CUST0004  Female   41   East            Books                4
# 4    CUST0005  Female   32   East            Books                2
#
#    Price_Per_Unit Purchase_Date  Total_Amount
# 0          417.22    12-06-2024        834.44
# 1          460.87    22-12-2024        460.87
# 2          145.25    10-07-2024        726.25
# 3          352.03    14-08-2024       1408.12
# 4           80.22    25-06-2024        160.44

# %%
print(df.columns)
print(df.dtypes)
print(df.shape)
# Out:
# Index(['Customer_ID', 'Gender', 'Age', 'Region', 'Product_Category',
#        'Units_Purchased', 'Price_Per_Unit', 'Purchase_Date', 'Total_Amount'],
#       dtype='str')
# Customer_ID             str
# Gender                  str
# Age                   int64
# Region                  str
# Product_Category        str
# Units_Purchased       int64
# Price_Per_Unit      float64
# Purchase_Date           str
# Total_Amount        float64
# dtype: object
# (150, 9)

# %%
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'] , format='mixed' , dayfirst=True)
print(df.isnull().sum())
print(df.duplicated().sum())
df.drop_duplicates(inplace=True)
# Out:
# Customer_ID         0
# Gender              0
# Age                 0
# Region              0
# Product_Category    0
# Units_Purchased     0
# Price_Per_Unit      0
# Purchase_Date       0
# Total_Amount        0
# dtype: int64
# 0

# %%
df['Month'] = df['Purchase_Date'].dt.month_name()

df['Month_Number'] = df['Purchase_Date'].dt.month

df['Week'] = df['Purchase_Date'].dt.isocalendar().week

df['Day'] = df['Purchase_Date'].dt.day_name()

df['Year'] = df['Purchase_Date'].dt.year

print(df)
# Out:
#     Customer_ID  Gender  Age Region Product_Category  Units_Purchased  \
# 0      CUST0001  Female   51   West           Sports                2
# 1      CUST0002  Female   55   East            Books                1
# 2      CUST0003  Female   50  North        Groceries                5
# 3      CUST0004  Female   41   East            Books                4
# 4      CUST0005  Female   32   East            Books                2
# ..          ...     ...  ...    ...              ...              ...
# 145    CUST0146  Female   21   East           Sports                4
# 146    CUST0147  Female   47  North           Sports                1
# 147    CUST0148    Male   28  North        Groceries                5
# 148    CUST0149    Male   47  North         Clothing                5
# 149    CUST0150    Male   48  North           Sports                1
#
#      Price_Per_Unit Purchase_Date  Total_Amount      Month  Month_Number  \
# 0            417.22    2024-06-12        834.44       June             6
# 1            460.87    2024-12-22        460.87   December            12
# 2            145.25    2024-07-10        726.25       July             7
# 3            352.03    2024-08-14       1408.12     August             8
# 4             80.22    2024-06-25        160.44       June             6
# ..              ...           ...           ...        ...           ...
# 145          252.47    2024-09-28       1009.88  September             9
# 146          681.68    2024-12-23        681.68   December            12
# 147          243.49    2024-06-04       1217.45       June             6
# 148          448.26    2024-01-08       2241.30    January             1
# 149          464.84    2024-05-01        464.84        May             5
#
#      Week        Day  Year
# 0      24  Wednesday  2024
# 1      51     Sunday  2024
# 2      28  Wednesday  2024
# 3      33  Wednesday  2024
# 4      26    Tuesday  2024
# ..    ...        ...   ...
# 145    39   Saturday  2024
# 146    52     Monday  2024
# 147    23    Tuesday  2024
# 148     2     Monday  2024
# 149    18  Wednesday  2024
#
# [150 rows x 14 columns]

# %%
sales = np.array(df['Total_Amount'])

units = np.array(df['Units_Purchased'])

print(np.mean(sales))

print(df['Total_Amount'].mean())
print(np.array(df['Total_Amount']).mean())
print(np.median(sales))
print(np.max(sales))
# Out:
# 1595.1979999999999
# 1595.1979999999999
# 1595.1979999999999
# 1238.705
# 6220.4
